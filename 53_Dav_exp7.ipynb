# %% [markdown]
# Sentence tokenization

# %%
import nltk
nltk.download('punkt')
sentence_data = "The First sentence is about Python. The Second: about Django. You can learn Python,Django and Data Ananlysis here. "
nltk_tokens = nltk.sent_tokenize(sentence_data)
print(nltk_tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['The First sentence is about Python.', 'The Second: about Django.', 'You can learn Python,Django and Data Ananlysis here.']

# %% [markdown]
# Word tokenization

# %%
tokens = nltk.word_tokenize(sentence_data)
print(tokens)
# Out:
# ['The', 'First', 'sentence', 'is', 'about', 'Python', '.', 'The', 'Second', ':', 'about', 'Django', '.', 'You', 'can', 'learn', 'Python', ',', 'Django', 'and', 'Data', 'Ananlysis', 'here', '.']

# %% [markdown]
# Frequency distribution

# %%
from nltk.probability import FreqDist

fdist = FreqDist(tokens)
print(fdist.most_common(6))
# Out:
# [('.', 3), ('The', 2), ('about', 2), ('Python', 2), ('Django', 2), ('First', 1)]

# %%
import matplotlib.pyplot as plt

fdist.plot(30,cumulative=False)
plt.show()

# %% [markdown]
# Stopwords

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words=set(stopwords.words("english"))

print(stop_words)
# Out:
# {'for', 'couldn', 'she', 'them', 'as', 'theirs', 'doesn', 'most', 'over', 'ours', 'about', 'not', 'does', 'should', 'during', 'mustn', 'but', 'didn', 'so', 'very', 'been', 'just', 'where', 'hasn', 'against', 'have', 'which', 'same', 'is', 'the', 'doing', 'weren', 'between', 'through', "she's", 'll', 'him', 'from', 'me', 'only', 'than', "should've", "mustn't", 'my', 'was', 'what', 'yourself', 'those', 'these', "didn't", 'again', 'wasn', 't', 're', 'y', 'o', 'while', 've', 'will', "you'll", 'their', 'few', 's', 'both', 'into', 'herself', 'before', 'nor', 'on', 'who', "mightn't", 'here', 'out', 'at', 'with', "weren't", 'if', 'they', "shan't", "isn't", 'and', 'in', 'hadn', 'until', 'had', 'after', 'this', 'needn', 'once', 'ma', 'then', 'no', 'too', "you've", 'do', 'having', 'yourselves', 'our', 'shan', 'i', 'below', 'why', "don't", 'of', 'your', 'isn', 'when', 'he', "wouldn't", 'each', "it's", 'up', 'down', "that'll", 'such', "needn't", 'mightn', 'above', 'did', 'are', 'how', 'some', 'ow
# ...

# %%
filtered_tokens=[]
for w in tokens:
    if w not in stop_words:
         filtered_tokens.append(w)
print("Filterd Tokens:",filtered_tokens)
# Out:
# Filterd Tokens: ['The', 'First', 'sentence', 'Python', '.', 'The', 'Second', ':', 'Django', '.', 'You', 'learn', 'Python', ',', 'Django', 'Data', 'Ananlysis', '.']

# %% [markdown]
# Removing Punctuations

# %%
import string

# punctuations
punctuations=list(string.punctuation)

filtered_tokens2=[]

for i in filtered_tokens:
    if i not in punctuations:
        filtered_tokens2.append(i)

print("Filterd Tokens After Removing Punctuations:",filtered_tokens2)
# Out:
# Filterd Tokens After Removing Punctuations: ['The', 'First', 'sentence', 'Python', 'The', 'Second', 'Django', 'You', 'learn', 'Python', 'Django', 'Data', 'Ananlysis']

# %% [markdown]
# Lexicon Normalization

# %% [markdown]
# Stemming

# %%
# Stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
ps = PorterStemmer()

stemmed_words=[]

for w in filtered_tokens2:
     stemmed_words.append(ps.stem(w))

print("Filtered Tokens After Removing Punctuations:",filtered_tokens2)
print("Stemmed Tokens:",stemmed_words)
# Out:
# Filtered Tokens After Removing Punctuations: ['The', 'First', 'sentence', 'Python', 'The', 'Second', 'Django', 'You', 'learn', 'Python', 'Django', 'Data', 'Ananlysis']
# Stemmed Tokens: ['the', 'first', 'sentenc', 'python', 'the', 'second', 'django', 'you', 'learn', 'python', 'django', 'data', 'ananlysi']

# %% [markdown]
# Lemmatization

# %%
data='For example, when you’re planning your next trip, Discover might show an article with the best places to eat or sights to see. Suddenly, a travel article published three months ago is timely for you. This can also be useful as you’re taking up a new hobby or going deeper on a long-time interest. Using the Topic Layer in the Knowledge Graph, Discover can predict your level of expertise on a topic and help you further develop those interests. If you’re learning to play guitar, for example, you might see beginner content about learning chords. If you’re already a skilled musician, you may see a video on more advanced techniques.'
tokens = nltk.word_tokenize(data)
import string

# punctuations
punctuations=list(string.punctuation)

filtered_tokens3=[]

for i in tokens:
    if i not in punctuations:
        filtered_tokens3.append(i)

filtered_tokens4=[]
for w in filtered_tokens3:
    if w not in stop_words:
         filtered_tokens4.append(w)


print(filtered_tokens4)
# Out:
# Filterd Tokens After Removing Punctuations: ['For', 'example', '’', 'planning', 'next', 'trip', 'Discover', 'might', 'show', 'article', 'best', 'places', 'eat', 'sights', 'see', 'Suddenly', 'travel', 'article', 'published', 'three', 'months', 'ago', 'timely', 'This', 'also', 'useful', '’', 'taking', 'new', 'hobby', 'going', 'deeper', 'long-time', 'interest', 'Using', 'Topic', 'Layer', 'Knowledge', 'Graph', 'Discover', 'predict', 'level', 'expertise', 'topic', 'help', 'develop', 'interests', 'If', '’', 'learning', 'play', 'guitar', 'example', 'might', 'see', 'beginner', 'content', 'learning', 'chords', 'If', '’', 'already', 'skilled', 'musician', 'may', 'see', 'video', 'advanced', 'techniques']

# %%
#Lexicon Normalization#performing stemming and Lemmatization
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
nltk.download('wordnet')
lem = WordNetLemmatizer()
stem = PorterStemmer()

list1=[]
for i in filtered_tokens4:
  list1.append(lem.lemmatize(i,"v"))


print(list1)
# Out:
# ['For', 'example', '’', 'plan', 'next', 'trip', 'Discover', 'might', 'show', 'article', 'best', 'place', 'eat', 'sight', 'see', 'Suddenly', 'travel', 'article', 'publish', 'three', 'months', 'ago', 'timely', 'This', 'also', 'useful', '’', 'take', 'new', 'hobby', 'go', 'deeper', 'long-time', 'interest', 'Using', 'Topic', 'Layer', 'Knowledge', 'Graph', 'Discover', 'predict', 'level', 'expertise', 'topic', 'help', 'develop', 'interest', 'If', '’', 'learn', 'play', 'guitar', 'example', 'might', 'see', 'beginner', 'content', 'learn', 'chord', 'If', '’', 'already', 'skilled', 'musician', 'may', 'see', 'video', 'advance', 'techniques']
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
#  Part-of-Speech(POS) tagging

# %%
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger')
pos_=pos_tag(tokens)


print("Tokens:",tokens)
print("PoS tags:",pos_)
# Out:
# Tokens: ['For', 'example', ',', 'when', 'you', '’', 're', 'planning', 'your', 'next', 'trip', ',', 'Discover', 'might', 'show', 'an', 'article', 'with', 'the', 'best', 'places', 'to', 'eat', 'or', 'sights', 'to', 'see', '.', 'Suddenly', ',', 'a', 'travel', 'article', 'published', 'three', 'months', 'ago', 'is', 'timely', 'for', 'you', '.', 'This', 'can', 'also', 'be', 'useful', 'as', 'you', '’', 're', 'taking', 'up', 'a', 'new', 'hobby', 'or', 'going', 'deeper', 'on', 'a', 'long-time', 'interest', '.', 'Using', 'the', 'Topic', 'Layer', 'in', 'the', 'Knowledge', 'Graph', ',', 'Discover', 'can', 'predict', 'your', 'level', 'of', 'expertise', 'on', 'a', 'topic', 'and', 'help', 'you', 'further', 'develop', 'those', 'interests', '.', 'If', 'you', '’', 're', 'learning', 'to', 'play', 'guitar', ',', 'for', 'example', ',', 'you', 'might', 'see', 'beginner', 'content', 'about', 'learning', 'chords', '.', 'If', 'you', '’', 're', 'already', 'a', 'skilled', 'musician', ',', 'you', 'may', 'see', 
# ...

# %% [markdown]
# Named Entity Recognition

# %%
from nltk import ne_chunk
nltk.download('maxent_ne_chunker')
nltk.download('words')

data="New York City on Tuesday declared a public health emergency and ordered mandatory measles vaccinations amid an outbreak, becoming the latest national flash point over refusals to inoculate against dangerous diseases."

for chunk in ne_chunk(nltk.pos_tag(word_tokenize(data))):
        if hasattr(chunk, 'label'):
            print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# GPE New York City
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# R

# %%
data<-'data="New York City on Tuesday declared a public health emergency and ordered mandatory measles vaccinations amid an outbreak, becoming the latest national flash point over refusals to inoculate against dangerous diseases."'

# %%
library(textstem)

# Your provided text
data <- 'New York City on Tuesday declared a public health emergency and ordered mandatory measles vaccinations amid an outbreak, becoming the latest national flash point over refusals to inoculate against dangerous diseases.'

# Lemmatization
lemmatized_text <- lemmatize_strings(data)

# Print the original and lemmatized text
data.frame(Original = data, Lemmatized = lemmatized_text, stringsAsFactors = FALSE)
# Out:
#   Original
# 1 New York City on Tuesday declared a public health emergency and ordered mandatory measles vaccinations amid an outbreak, becoming the latest national flash point over refusals to inoculate against dangerous diseases.
#   Lemmatized
# 1 New York City on Tuesday declare a public health emergency and order mandatory measle vaccination amid a outbreak, become the late national flash point over refusal to inoculate against dangerous disease.

# %%
install.packages(c("tm", "textclean"))
require(tm)# Sample text data

# Create a corpus from the text data
corpus <- Corpus(VectorSource(data))

# Preprocessing steps
corpus <- tm_map(corpus, content_transformer(tolower))  # Convert to lowercase
corpus <- tm_map(corpus, removeNumbers)                # Remove numbers
corpus <- tm_map(corpus, removePunctuation)            # Remove punctuation
corpus <- tm_map(corpus, removeWords, stopwords("english"))  # Remove stopwords

# Check the preprocessed text
inspect(corpus)
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in tm_map.SimpleCorpus(corpus, content_transformer(tolower)):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(corpus, removeNumbers):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(corpus, removePunctuation):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(corpus, removeWords, stopwords("english")):
# “transformation drops documents”
# <<SimpleCorpus>>
# Metadata:  corpus specific: 1, document level (indexed): 0
# Content:  documents: 1
#
# [1] datanew york city  tuesday declared  public health emergency  ordered mandatory measles vaccinations amid  outbreak becoming  latest national flash point  refusals  inoculate  dangerous diseases

# %% [markdown]
# install.packages(c("rvest", "httr"))
# library(rvest)
# library(httr)

# %%
url <- "https://www.tripadvisor.in/"
page <- read_html(url)
titles <- page %>% html_nodes("h2") %>% html_text()
print("Scraped Titles:")
print(titles)
# Out:
# [1] "Scraped Titles:"
# [1] "Take a trip to a traveller fave"
# [2] "Top experiences on Tripadvisor"
# [3] "Vibrant Asian cities"
# [4] "More to explore"
# [5] "Top destinations for your next holiday"
# [6] "Watch The Wanderer Season 1 on Amazon Prime Video"
# [7] "Travellers' Choice Awards\nBest of the Best"
